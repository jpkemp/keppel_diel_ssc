# %%
from IPython.display import display
from backend.eda import create_boxplots
from tools.io import unpickle_data

# %%
load_saved_sscodes:str = "data/formatted_sscodes.pkl"
sscodes = unpickle_data(load_saved_sscodes, False)

# %%
fltr = "broad"
figs = create_boxplots(fltr, sscodes[fltr])
for metric, fig in figs:
    print(f"Boxplot for {metric}")
    display(fig)
# Out:
# Boxplot for acorr3
# Boxplot for B
# Boxplot for lprms
# Boxplot for lppk
# Boxplot for D

# %%
fltr = "fish"
figs = create_boxplots(fltr, sscodes[fltr])
for metric, fig in figs:
    print(f"Boxplot for {metric}")
    display(fig)
# Out:
# Boxplot for acorr3
# Boxplot for B
# Boxplot for lprms
# Boxplot for lppk
# Boxplot for D

# %%
fltr = "invertebrate"
figs = create_boxplots(fltr, sscodes[fltr])
for metric, fig in figs:
    print(f"Boxplot for {metric}")
    display(fig)
# Out:
# Boxplot for acorr3
# Boxplot for B
# Boxplot for lprms
# Boxplot for lppk
# Boxplot for D
